# %% [markdown]
# these are where lecture notes will be written to explain code

# %% [markdown]
# example: there are diffferent ways of changing fonts...

# %%
print("Hello world")
# Out:
# Hello world
